# %%
import pandas as pd

# %%
df = pd.read_csv("Hospitaldata.csv")

# %%
df
# Out:
#                            Hospital Name                        Address  \
# 0          MARSHALL MEDICAL CENTER SOUTH     2505 U S HIGHWAY 431 NORTH
# 1         DEKALB REGIONAL MEDICAL CENTER           200 MED CENTER DRIVE
# 2                       WEDOWEE HOSPITAL          209 NORTH MAIN STREET
# 3                   HALE COUNTY HOSPITAL               508 GREEN STREET
# 4               CRESTWOOD MEDICAL CENTER             ONE HOSPITAL DR SE
# ...                                  ...                            ...
# 4807  CLEAR LAKE REGIONAL MEDICAL CENTER        500 MEDICAL CENTER BLVD
# 4808   ORTHOPAEDIC HOSPITAL OF WISCONSIN         475 W RIVER WOODS PKWY
# 4809   CARILION GILES COMMUNITY HOSPITAL                159 HARTLEY WAY
# 4810            PLEASANT VALLEY HOSPITAL              2520 VALLEY DRIVE
# 4811          JOHNSTON MEMORIAL HOSPITAL  16000 JOHNSTON MEMORIAL DRIVE
#
#                 City State  ZIP_Code County_Name              Hospital_Type  \
# ...

# %%
# 1.check all the hostipal in a particular city
df1 = df[df["City"] == 'CHICAGO']
df1
# Out:
#                                           Hospital Name  \
# 67                     MT SINAI HOSPITAL MEDICAL CENTER
# 79    ANN & ROBERT H LURIE CHILDRENS HOSPITAL OF CHI...
# 80                        LARABIDA CHILDRENS HOSPITAL I
# 1371                             SAINT ANTHONY HOSPITAL
# 1376                              JACKSON PARK HOSPITAL
# 1380               PRESENCE RESURRECTION MEDICAL CENTER
# 1445                      METHODIST HOSPITAL OF CHICAGO
# 1479                    LOUIS A WEISS MEMORIAL HOSPITAL
# 1503                        NORWEGIAN-AMERICAN HOSPITAL
# 1583                          SWEDISH COVENANT HOSPITAL
# 1611                  MERCY HOSPITAL AND MEDICAL CENTER
# 1643                               SOUTH SHORE HOSPITAL
# 1710                          ADVOCATE TRINITY HOSPITAL
# 1727                     NORTHWESTERN MEMORIAL HOSPITAL
# 1817                    UNIVERSITY OF ILLINOIS HOSPITAL
# 1847                        ROSELAND COMMUNITY HOSPITAL
# ...

# %%
#2.check hospital in a particular city where there is a particular department 
df2 = df1[df1['Department'] == 'gynecology']
df2
# Out:
#                                           Hospital Name  \
# 67                     MT SINAI HOSPITAL MEDICAL CENTER
# 79    ANN & ROBERT H LURIE CHILDRENS HOSPITAL OF CHI...
# 80                        LARABIDA CHILDRENS HOSPITAL I
# 1371                             SAINT ANTHONY HOSPITAL
# 1380               PRESENCE RESURRECTION MEDICAL CENTER
# 1445                      METHODIST HOSPITAL OF CHICAGO
# 1479                    LOUIS A WEISS MEMORIAL HOSPITAL
# 1503                        NORWEGIAN-AMERICAN HOSPITAL
# 1643                               SOUTH SHORE HOSPITAL
# 1710                          ADVOCATE TRINITY HOSPITAL
# 1727                     NORTHWESTERN MEMORIAL HOSPITAL
# 1847                        ROSELAND COMMUNITY HOSPITAL
# 1856                                ST BERNARD HOSPITAL
# 1869  PRESENCE SAINTS MARY AND ELIZABETH MEDICAL CENTER
# 1924           THE UNIVERSITY OF CHICAGO MEDICAL CENTER
# 2054                     SHRINERS HOSPITAL FOR CHILDREN
# ...

# %%
#3.get the top rated hospital in a particular city or state
df3 = df2[df2['Rating'] >= 4.5]
df3
# Out:
#                        Hospital Name                     Address     City  \
# 80     LARABIDA CHILDRENS HOSPITAL I  E 65TH ST AT LAKE MICHIGAN  CHICAGO
# 1503     NORWEGIAN-AMERICAN HOSPITAL        1044 N FRANCISCO AVE  CHICAGO
# 1727  NORTHWESTERN MEMORIAL HOSPITAL              251 E HURON ST  CHICAGO
# 1847     ROSELAND COMMUNITY HOSPITAL           45 W 111TH STREET  CHICAGO
#
#      State  ZIP_Code County_Name         Hospital_Type  \
# 80      IL     60649        COOK             Childrens
# 1503    IL     60622        COOK  Acute Care Hospitals
# 1727    IL     60611        COOK  Acute Care Hospitals
# 1847    IL     60628        COOK  Acute Care Hospitals
#
#                   Hospital_Ownership  Rooms_available   Department  Bed_Grade  \
# 80    Voluntary non-profit - Private                 2  gynecology        2.0
# 1503  Voluntary non-profit - Private                 4  gynecology        2.0
# 1727  Voluntary non-profit - Private                 4  gynecology        2.0
# ...

# %%
#4.get the list of nearest hospital from the where by providing zip code.
df[df['ZIP_Code'] == 60611]
# Out:
#                                           Hospital Name  \
# 79    ANN & ROBERT H LURIE CHILDRENS HOSPITAL OF CHI...
# 1727                     NORTHWESTERN MEMORIAL HOSPITAL
#
#                     Address     City State  ZIP_Code County_Name  \
# 79    225 E CHICAGO. BOX 57  CHICAGO    IL     60611        COOK
# 1727         251 E HURON ST  CHICAGO    IL     60611        COOK
#
#              Hospital_Type              Hospital_Ownership  Rooms_available   \
# 79               Childrens    Voluntary non-profit - Other                 3
# 1727  Acute Care Hospitals  Voluntary non-profit - Private                 4
#
#       Department  Bed_Grade  patientID Type_of_Admission Severity_of_Illness  \
# 79    gynecology        2.0     143300            Trauma               Minor
# 1727  gynecology        2.0     140281            Trauma            Moderate
#
#       Visitors_with_Patient    Age  Admission_Deposit   Stay  Rating
# ...

# %%
#5.get the list of hospital  where type of hospitals is Acute care hospitals are there in a particular state.
df5 = df[df['Hospital_Type'] == 'Acute Care Hospitals']
df5
# Out:
#                            Hospital Name                        Address  \
# 0          MARSHALL MEDICAL CENTER SOUTH     2505 U S HIGHWAY 431 NORTH
# 1         DEKALB REGIONAL MEDICAL CENTER           200 MED CENTER DRIVE
# 2                       WEDOWEE HOSPITAL          209 NORTH MAIN STREET
# 3                   HALE COUNTY HOSPITAL               508 GREEN STREET
# 4               CRESTWOOD MEDICAL CENTER             ONE HOSPITAL DR SE
# ...                                  ...                            ...
# 4806            VIRGINIA HOSPITAL CENTER  1701 NORTH GEORGE MASON DRIVE
# 4807  CLEAR LAKE REGIONAL MEDICAL CENTER        500 MEDICAL CENTER BLVD
# 4808   ORTHOPAEDIC HOSPITAL OF WISCONSIN         475 W RIVER WOODS PKWY
# 4810            PLEASANT VALLEY HOSPITAL              2520 VALLEY DRIVE
# 4811          JOHNSTON MEMORIAL HOSPITAL  16000 JOHNSTON MEMORIAL DRIVE
#
#                 City State  ZIP_Code County_Name         Hospital_Type  \
# ...

# %%
df5[df5['State'] == "AZ"]
# Out:
#                                    Hospital Name  \
# 10                 FORT DEFIANCE INDIAN HOSPITAL
# 11    TUBA CITY REGIONAL HEALTH CARE CORPORATION
# 12                                SELLS HOSPITAL
# 13                  SAN CARLOS APACHE HEALTHCARE
# 14     CHINLE COMPREHENSIVE HEALTH CARE FACILITY
# ...                                          ...
# 1244                    NORTHWEST MEDICAL CENTER
# 1273              SCOTTSDALE SHEA MEDICAL CENTER
# 1277                BANNER PAYSON MEDICAL CENTER
# 1325                    ABRAZO SCOTTSDALE CAMPUS
# 1338                          ABRAZO WEST CAMPUS
#
#                              Address           City State  ZIP_Code  \
# 10                        PO BOX 649  FORT DEFIANCE    AZ     86504
# 11                        PO BOX 600      TUBA CITY    AZ     86045
# 12        HIGHWAY 86. AT TOPAWA ROAD          SELLS    AZ     85634
# 13             103 MEDICINE WAY ROAD        PERIDOT    AZ     85542
# ...

# %%
#6.get the hospital info where the particular patient is admitted by using patientID.

df[df["patientID"] == 30085]
# Out:
#                  Hospital Name                         Address    City State  \
# 1244  NORTHWEST MEDICAL CENTER  6200 NORTH LA CHOLLA BOULEVARD  TUCSON    AZ
#
#       ZIP_Code County_Name         Hospital_Type Hospital_Ownership  \
# 1244     85741        PIMA  Acute Care Hospitals        Proprietary
#
#       Rooms_available   Department  Bed_Grade  patientID Type_of_Admission  \
# 1244                 2  anesthesia        3.0      30085         Emergency
#
#      Severity_of_Illness  Visitors_with_Patient    Age  Admission_Deposit  \
# 1244             Extreme                      6  31-40               5280
#
#        Stay  Rating
# 1244  51-60    3.75

# %%
#7.get the list of hospital which is for senior citizen and child care
df[df["Hospital_Type"] == 'Childrens']
# Out:
#                                           Hospital Name  \
# 38                       CHILDREN'S HOSP OF LOS ANGELES
# 39                       CHILDREN'S HOSPITAL AT MISSION
# 60    CHILDREN'S HEALTHCARE OF ATLANTA AT SCOTTISH RITE
# 79    ANN & ROBERT H LURIE CHILDRENS HOSPITAL OF CHI...
# 80                        LARABIDA CHILDRENS HOSPITAL I
# ...                                                 ...
# 4577                 CHILDREN'S HOSPITAL OF SAN ANTONIO
# 4611                     SHRINERS HOSPITAL FOR CHILDREN
# 4625            SHRINERS HOSPITALS FOR CHILDREN - S L C
# 4732                    CHILDRENS MEDICAL CTR OF DALLAS
# 4803                         PRIMARY CHILDRENS HOSPITAL
#
#                                  Address            City State  ZIP_Code  \
# 38                      4650 SUNSET BLVD     LOS ANGELES    CA     90027
# 39    27700 MEDICAL CENTER RD. 5TH FLOOR   MISSION VIEJO    CA     92691
# ...

# %%
#8.Get the list of hospitals which are  acute care and critical accessable.
df[df["Hospital_Type"] == 'Acute Care Hospitals']
# Out:
#                            Hospital Name                        Address  \
# 0          MARSHALL MEDICAL CENTER SOUTH     2505 U S HIGHWAY 431 NORTH
# 1         DEKALB REGIONAL MEDICAL CENTER           200 MED CENTER DRIVE
# 2                       WEDOWEE HOSPITAL          209 NORTH MAIN STREET
# 3                   HALE COUNTY HOSPITAL               508 GREEN STREET
# 4               CRESTWOOD MEDICAL CENTER             ONE HOSPITAL DR SE
# ...                                  ...                            ...
# 4806            VIRGINIA HOSPITAL CENTER  1701 NORTH GEORGE MASON DRIVE
# 4807  CLEAR LAKE REGIONAL MEDICAL CENTER        500 MEDICAL CENTER BLVD
# 4808   ORTHOPAEDIC HOSPITAL OF WISCONSIN         475 W RIVER WOODS PKWY
# 4810            PLEASANT VALLEY HOSPITAL              2520 VALLEY DRIVE
# 4811          JOHNSTON MEMORIAL HOSPITAL  16000 JOHNSTON MEMORIAL DRIVE
#
#                 City State  ZIP_Code County_Name         Hospital_Type  \
# ...

# %%
df[df["Hospital_Type"] == 'Critical Access Hospitals']
# Out:
#                           Hospital Name  \
# 5              CHOCTAW GENERAL HOSPITAL
# 7        NORTON SOUND REGIONAL HOSPITAL
# 8                    KANAKANAK HOSPITAL
# 9                MANIILAQ HEALTH CENTER
# 15              HOPI HEALTH CARE CENTER
# ...                                 ...
# 4787         OCHILTREE GENERAL HOSPITAL
# 4794        COLUMBUS COMMUNITY HOSPITAL
# 4799           GOODALL WITCHER HOSPITAL
# 4801                   SKYLINE HOSPITAL
# 4809  CARILION GILES COMMUNITY HOSPITAL
#
#                                       Address          City State  ZIP_Code  \
# 5            401 VANITY FAIR LANE. PO BOX 618        BUTLER    AL     36904
# 7     1000 GREG KRUSCHEK AVENUE (P O BOX 966)          NOME    AK     99762
# 8                                 P O BOX 130    DILLINGHAM    AK     99576
# 9                                   PO BOX 43      KOTZEBUE    AK     99752
# 15                  HIGHWAY 264. MILEPOST 388       POLACCA    AZ     86042
# ...

# %%
#9.Hospitals which provides emergency services
df[df["Type_of_Admission"] == "Emergency"]
# Out:
#                                   Hospital Name  \
# 0                 MARSHALL MEDICAL CENTER SOUTH
# 6            YUKON KUSKOKWIM DELTA REG HOSPITAL
# 12                               SELLS HOSPITAL
# 14    CHINLE COMPREHENSIVE HEALTH CARE FACILITY
# 15                      HOPI HEALTH CARE CENTER
# ...                                         ...
# 4801                           SKYLINE HOSPITAL
# 4804               WALLA WALLA GENERAL HOSPITAL
# 4805             AURORA LAKELAND MEDICAL CENTER
# 4809          CARILION GILES COMMUNITY HOSPITAL
# 4811                 JOHNSTON MEMORIAL HOSPITAL
#
#                             Address          City State  ZIP_Code  \
# 0        2505 U S HIGHWAY 431 NORTH          BOAZ    AL     35957
# 6                        PO BOX 287        BETHEL    AK     99559
# 12       HIGHWAY 86. AT TOPAWA ROAD         SELLS    AZ     85634
# 14        US HWY 191. HOSPITAL ROAD        CHINLE    AZ     86503
# ...

# %%
#10.Hospitals having rating greater than 4
df[df['Rating'] > 4]
# Out:
#                                          Hospital Name  \
# 5                             CHOCTAW GENERAL HOSPITAL
# 10                       FORT DEFIANCE INDIAN HOSPITAL
# 11          TUBA CITY REGIONAL HEALTH CARE CORPORATION
# 12                                      SELLS HOSPITAL
# 13                        SAN CARLOS APACHE HEALTHCARE
# ...                                                ...
# 4769  TEXAS HEALTH HARRIS METHODIST HOSPITAL SOUTHLAKE
# 4770                            WARD MEMORIAL HOSPITAL
# 4780            SSM HEALTH ST CLARE HOSPITAL - BARABOO
# 4791                                SAMARITAN HOSPITAL
# 4799                          GOODALL WITCHER HOSPITAL
#
#                                Address           City State  ZIP_Code  \
# 5     401 VANITY FAIR LANE. PO BOX 618         BUTLER    AL     36904
# 10                          PO BOX 649  FORT DEFIANCE    AZ     86504
# 11                          PO BOX 600      TUBA CITY    AZ     86045
# ...

# %%
#11. Hospitals with room avaibility in a particular area
df11 = df1[df1["Rooms_available "] > 0]
df11
# Out:
#                                           Hospital Name  \
# 67                     MT SINAI HOSPITAL MEDICAL CENTER
# 79    ANN & ROBERT H LURIE CHILDRENS HOSPITAL OF CHI...
# 80                        LARABIDA CHILDRENS HOSPITAL I
# 1371                             SAINT ANTHONY HOSPITAL
# 1376                              JACKSON PARK HOSPITAL
# 1380               PRESENCE RESURRECTION MEDICAL CENTER
# 1445                      METHODIST HOSPITAL OF CHICAGO
# 1479                    LOUIS A WEISS MEMORIAL HOSPITAL
# 1503                        NORWEGIAN-AMERICAN HOSPITAL
# 1583                          SWEDISH COVENANT HOSPITAL
# 1611                  MERCY HOSPITAL AND MEDICAL CENTER
# 1643                               SOUTH SHORE HOSPITAL
# 1710                          ADVOCATE TRINITY HOSPITAL
# 1727                     NORTHWESTERN MEMORIAL HOSPITAL
# 1817                    UNIVERSITY OF ILLINOIS HOSPITAL
# 1847                        ROSELAND COMMUNITY HOSPITAL
# ...

# %%
df.columns.tolist()
# Out:
# ['Hospital Name',
#  'Address',
#  'City',
#  'State',
#  'ZIP_Code',
#  'County_Name',
#  'Hospital_Type',
#  'Hospital_Ownership',
#  'Rooms_available ',
#  'Department',
#  'Bed_Grade',
#  'patientID',
#  'Type_of_Admission',
#  'Severity_of_Illness',
#  'Visitors_with_Patient',
#  'Age',
#  'Admission_Deposit',
#  'Stay',
#  'Rating']

# %%
#12. Hospitals which is owed by hospital or Tribal
df[df['Hospital_Ownership'] == "Tribal"]
# Out:
#                                  Hospital Name  \
# 6           YUKON KUSKOKWIM DELTA REG HOSPITAL
# 7               NORTON SOUND REGIONAL HOSPITAL
# 9                       MANIILAQ HEALTH CENTER
# 12                              SELLS HOSPITAL
# 15                     HOPI HEALTH CARE CENTER
# 3619    MUSCOGEE (CREEK) NATION MEDICAL CENTER
# 3712  CHOCTAW NATION HEALTH SERVICES AUTHORITY
# 3733           CREEK NATION COMMUNITY HOSPITAL
# 3957                 CLAREMORE INDIAN HOSPITAL
#
#                                       Address       City State  ZIP_Code  \
# 6                                  PO BOX 287     BETHEL    AK     99559
# 7     1000 GREG KRUSCHEK AVENUE (P O BOX 966)       NOME    AK     99762
# 9                                   PO BOX 43   KOTZEBUE    AK     99752
# 12                 HIGHWAY 86. AT TOPAWA ROAD      SELLS    AZ     85634
# 15                  HIGHWAY 264. MILEPOST 388    POLACCA    AZ     86042
# ...

# %%
#13.Number of rooms available in a hospital in a particular city
df11['Rooms_available '].value_counts()
# Out:
# 2    13
# 4     7
# 3     6
# 1     1
# 6     1
# 9     1
# Name: Rooms_available , dtype: int64
